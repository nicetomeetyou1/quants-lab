# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

# 2. The executors dataframe: this is the dataframe that contains the information of the orders that were executed
warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.backtesting import BacktestingEngine

backtesting = BacktestingEngine(root_path=root_path, load_cached_data=False)

# %%
from hummingbot.strategy_v2.executors.position_executor.data_types import TrailingStop
from controllers.directional_trading.macd_bb_v1 import MACDBBV1ControllerConfig
import datetime
from decimal import Decimal

import pandas as pd
import pandas_ta as ta 


# Controller configuration
connector_name = "bybit_perpetual"
trading_pair = "WAL-USDT"
candles_connector="bybit_perpetual"
candles_trading_pair="WAL-USDT"
interval = "1m"
fast_ma = 21
slow_ma = 42
signal_ma = 9
bb_length = 200
natr_length = 200
bb_std = 2
total_amount_quote = 1000
max_executors_per_side = 5
take_profit = 0.01
stop_loss = 0.03
trailing_stop_activation_price = 0.007
trailing_stop_trailing_delta = 0.003
time_limit = 60 * 60
cooldown_time = 60 * 15
leverage = 10

start = int(datetime.datetime(2025, 4, 26).timestamp())
end = int(datetime.datetime(2025, 4, 27).timestamp())

# Creating the instance of the configuration and the controller
config = MACDBBV1ControllerConfig(
    connector_name=connector_name,
    trading_pair=trading_pair,
    interval=interval,
    macd_fast=fast_ma,
    macd_slow=slow_ma,
    macd_signal=signal_ma,
    bb_length=bb_length,
    candles_connector=candles_connector,
    candles_trading_pair=candles_trading_pair,
    bb_std=bb_std,
    leverage=leverage,
    total_amount_quote=Decimal(total_amount_quote),
    take_profit=Decimal(take_profit),
    stop_loss=Decimal(stop_loss),
    trailing_stop=TrailingStop(activation_price=Decimal(trailing_stop_activation_price), trailing_delta=Decimal(trailing_stop_trailing_delta)),
    time_limit=time_limit,
    max_executors_per_side=max_executors_per_side,
    cooldown_time=cooldown_time,
)

# %%
backtesting_result = await backtesting.run_backtesting(config, start, end, interval)

# %%
# Let's see what is inside the backtesting results
print(backtesting_result.get_results_summary())
backtesting_result.get_backtesting_figure()
# Out:
# Net PNL: $-75.02 (-7.50%) | Max Drawdown: $-131.16 (-13.08%)
# Total Volume ($): 84000.00 | Sharpe Ratio: 0.19 | Profit Factor: 0.68
# Total Executors: 210 | Accuracy Long: 0.53 | Accuracy Short: 0.56
# Close Types: Take Profit: 50 | Stop Loss: 20 | Time Limit: 95 |
#              Trailing Stop: 45 | Early Stop: 0

# %%
# 2. The executors dataframe: this is the dataframe that contains the information of the orders that were executed
import pandas as pd

executors_df = backtesting_result.executors_df
executors_df.head()
# Out:
#                                              id  timestamp               type  \
# 0  ArDyU46VaX8qwMKg7BPZt7Lni61thaHLCqMzPu8uNSCM 1745104080  position_executor
# 1  5T6U9TY9C5h5DMACMrmEFiBHhEhxe2AazA8XpbabF8wU 1745104080  position_executor
# 2  4NBrkwo9M4SaJsNFv1iVfTJL3pogYb34XXJnD1eawdmN 1745104080  position_executor
# 3  H95Ks3NRw2ieWDk348S9k7NZgQ3CE5pHiNq4mKJ83mnW 1745104080  position_executor
# 4  281JGKgfZuPX93LTLDiW8qsGDMAPbNTKzaTCkzjTZrv3 1745104080  position_executor
#
#                       status  \
# 0  RunnableStatus.TERMINATED
# 1  RunnableStatus.TERMINATED
# 2  RunnableStatus.TERMINATED
# 3  RunnableStatus.TERMINATED
# 4  RunnableStatus.TERMINATED
#
#                                               config  \
# 0  {'id': 'ArDyU46VaX8qwMKg7BPZt7Lni61thaHLCqMzPu...
# 1  {'id': '5T6U9TY9C5h5DMACMrmEFiBHhEhxe2AazA8Xpb...
# 2  {'id': '4NBrkwo9M4SaJsNFv1iVfTJL3pogYb34XXJnD1...
# 3  {'id': 'H95Ks3NRw2ieWDk348S9k7NZgQ3CE5pHiNq4mK...
# 4  {'id': '281JGKgfZuPX93LTLDiW8qsGDMAPbNTKzaTCkz...
#
#                                          net_pnl_pct  \
# 0  0.01315200550080168964695026545541622908785939...
# 1  0.01315200550080168964695026545541622908785939...
# 2  0.01315200550080168964695026545541622908785939...
# 3  0.01315200550080168964695026545541622908785939...
# 4  0.01315200550080168964695026545541622908785939...
#
#                                        net_pnl_quote  \
# 0  2.63040110016033779061217501293867826461791992...
# 1  2.63040110016033779061217501293867826461791992...
# 2  2.63040110016033779061217501293867826461791992...
# 3  2.63040110016033779061217501293867826461791992...
# 4  2.63040110016033779061217501293867826461791992...
#
#                                       cum_fees_quote filled_amount_quote  \
# 0  0.11999999999999999555910790149937383830547332...                 400
# 1  0.11999999999999999555910790149937383830547332...                 400
# 2  0.11999999999999999555910790149937383830547332...                 400
# 3  0.11999999999999999555910790149937383830547332...                 400
# 4  0.11999999999999999555910790149937383830547332...                 400
#
#    is_active  is_trading                                        custom_info  \
# 0      False       False  {'close_price': 0.4303, 'level_id': None, 'sid...
# 1      False       False  {'close_price': 0.4303, 'level_id': None, 'sid...
# 2      False       False  {'close_price': 0.4303, 'level_id': None, 'sid...
# 3      False       False  {'close_price': 0.4303, 'level_id': None, 'sid...
# 4      False       False  {'close_price': 0.4303, 'level_id': None, 'sid...
#
#    close_timestamp             close_type controller_id  side
# 0       1745107320  CloseType.TAKE_PROFIT          None  SELL
# 1       1745107320  CloseType.TAKE_PROFIT          None  SELL
# 2       1745107320  CloseType.TAKE_PROFIT          None  SELL
# 3       1745107320  CloseType.TAKE_PROFIT          None  SELL
# 4       1745107320  CloseType.TAKE_PROFIT          None  SELL

# %% [markdown]
# ### Backtesting Analysis

# %% [markdown]
# ### Scatter of PNL per Trade
# This bar chart illustrates the PNL for each individual trade. Positive PNLs are shown in green and negative PNLs in red, providing a clear view of profitable vs. unprofitable trades.

# %%
import plotly.express as px

# Create a new column for profitability
executors_df['profitable'] = executors_df['net_pnl_quote'] > 0

# Create the scatter plot
fig = px.scatter(
    executors_df,
    x="timestamp",
    y='net_pnl_quote',
    title='PNL per Trade',
    color='profitable',
    color_discrete_map={True: 'green', False: 'red'},
    labels={'timestamp': 'Timestamp', 'net_pnl_quote': 'Net PNL (Quote)'},
    hover_data=['filled_amount_quote', 'side']
)

# Customize the layout
fig.update_layout(
    xaxis_title="Timestamp",
    yaxis_title="Net PNL (Quote)",
    legend_title="Profitable",
    font=dict(size=12, color="white"),
    showlegend=False,
    plot_bgcolor='rgba(0,0,0,0.8)',  # Dark background
    paper_bgcolor='rgba(0,0,0,0.8)',  # Dark background for the entire plot area
    xaxis=dict(gridcolor="gray"),
    yaxis=dict(gridcolor="gray")
)

# Add a horizontal line at y=0 to clearly separate profits and losses
fig.add_hline(y=0, line_dash="dash", line_color="lightgray")

# Show the plot
fig.show()

# %% [markdown]
# ### Histogram of PNL Distribution
# The histogram displays the distribution of PNL values across all trades. It helps in understanding the frequency and range of profit and loss outcomes.

# %%
fig = px.histogram(executors_df, x='net_pnl_quote', title='PNL Distribution')
fig.show()

# %% [markdown]
# # Conclusion
