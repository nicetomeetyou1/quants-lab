# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

# 2. The executors dataframe: this is the dataframe that contains the information of the orders that were executed
warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.backtesting import BacktestingEngine

backtesting = BacktestingEngine(root_path=root_path, load_cached_data=False)

# %%
from hummingbot.strategy_v2.executors.position_executor.data_types import TrailingStop
from controllers.directional_trading.macd_bb_v1 import MACDBBV1ControllerConfig
import datetime
from decimal import Decimal

import pandas as pd
import pandas_ta as ta 


# Controller configuration
connector_name = "bybit_perpetual"
trading_pair = "WAL-USDT"
candles_connector="bybit_perpetual"
candles_trading_pair="WAL-USDT"
interval = "1m"
fast_ma = 21
slow_ma = 42
signal_ma = 9
bb_length = 200
natr_length = 200
bb_std = 2
total_amount_quote = 400
max_executors_per_side = 2
take_profit = 0.1
stop_loss = 0.3
trailing_stop_activation_price = 0.007
trailing_stop_trailing_delta = 0.003
time_limit = 60 * 60
cooldown_time = 60 * 15
leverage = 10

start = int(datetime.datetime(2025, 4, 26).timestamp())
end = int(datetime.datetime(2025, 4, 27).timestamp())

# Creating the instance of the configuration and the controller
config = MACDBBV1ControllerConfig(
    connector_name=connector_name,
    trading_pair=trading_pair,
    interval=interval,
    macd_fast=fast_ma,
    position_sizing_method="volatility",
    distribution_method="inverted_triangle",
    macd_slow=slow_ma,
    macd_signal=signal_ma,
    bb_length=bb_length,
    candles_connector=candles_connector,
    candles_trading_pair=candles_trading_pair,
    bb_std=bb_std,
    natr_length=natr_length,
    leverage=leverage,
    step_percentage="0.001",
    total_amount_quote=Decimal(total_amount_quote),
    take_profit=Decimal(take_profit),
    stop_loss=Decimal(stop_loss),
    trailing_stop=TrailingStop(activation_price=Decimal(trailing_stop_activation_price), trailing_delta=Decimal(trailing_stop_trailing_delta)),
    time_limit=time_limit,
    max_executors_per_side=max_executors_per_side,
    cooldown_time=cooldown_time,
)

# %%
backtesting_result = await backtesting.run_backtesting(config, start, end, interval)
# Out:
# 0.18869977630442966
# [1, 1]
# [Decimal('69.86293087909280153254048052'), Decimal('69.86293087909280153254048052')] 370.2332469455757034463821938 inverted_triangle volatility
# 0.1351179780030854
# [1, 1]
# [Decimal('49.43039253816916103991176648'), Decimal('49.43039253816916103991176648')] 365.8313517468447288400938071 inverted_triangle volatility
# 0.15473107931462693
# [1, 1]
# [Decimal('57.31842167609813516307463507'), Decimal('57.31842167609813516307463507')] 370.4389701796628686044950650 inverted_triangle volatility
# 0.15507958040321593
# [1, 1]
# [Decimal('57.60757072927783450500855643'), Decimal('57.60757072927783450500855643')] 371.4710252600297247905229548 inverted_triangle volatility
# 0.16287780270888613
# [1, 1]
# [Decimal('61.66110267230215216791084358'), Decimal('61.66110267230215216791084358')] 378.5727806170736382612333922 inverted_triangle volatility
# 0.16357594422411006
# [1, 1]
# [Decimal('62.50513726561332522862396551'), Decimal('62.50513726561332522862396551')] 382.1169277799006668470023708 inverted_triangle volatility

# %%
# Let's see what is inside the backtesting results
print(backtesting_result.get_results_summary())
backtesting_result.get_backtesting_figure()
# Out:
# Net PNL: $-0.69 (-0.17%) | Max Drawdown: $-0.78 (-0.19%)
# Total Volume ($): 768.07 | Sharpe Ratio: -0.86 | Profit Factor: 0.22
# Total Executors: 12 | Accuracy Long: 0.50 | Accuracy Short: 0.00
# Close Types: Take Profit: 4 | Stop Loss: 4 | Time Limit: 0 |
#              Trailing Stop: 4 | Early Stop: 0

# %%
# 2. The executors dataframe: this is the dataframe that contains the information of the orders that were executed
import pandas as pd

executors_df = backtesting_result.executors_df
executors_df.head()
# Out:
#                                              id  timestamp               type  \
# 0   RjyYXBRAbe6cicUGxyoic6dF3z7Tze6oD6fAqmSUW53 1745618820  position_executor
# 1  3Ea9w6xRTXnYouSNfa2pTbom11uCNVJLh7r7cQYfqKy1 1745618820  position_executor
# 2  GqeJCqCUSWzM3KBfdFJbKSYz1RYrBpFz4fQpR1Gv52UX 1745654100  position_executor
# 3  Hidd11AgCZnAwSFFsYqhkZvdAUWv1M4wP5bHB3mxdLKc 1745654100  position_executor
# 4  87bvByFXiXon6hHufD3wtU3NCi2XFUDtfCEqY9kW2gTF 1745658060  position_executor
#
#                       status  \
# 0  RunnableStatus.TERMINATED
# 1  RunnableStatus.TERMINATED
# 2  RunnableStatus.TERMINATED
# 3  RunnableStatus.TERMINATED
# 4  RunnableStatus.TERMINATED
#
#                                               config  \
# 0  {'id': 'RjyYXBRAbe6cicUGxyoic6dF3z7Tze6oD6fAqm...
# 1  {'id': '3Ea9w6xRTXnYouSNfa2pTbom11uCNVJLh7r7cQ...
# 2  {'id': 'GqeJCqCUSWzM3KBfdFJbKSYz1RYrBpFz4fQpR1...
# 3  {'id': 'Hidd11AgCZnAwSFFsYqhkZvdAUWv1M4wP5bHB3...
# 4  {'id': '87bvByFXiXon6hHufD3wtU3NCi2XFUDtfCEqY9...
#
#                                          net_pnl_pct  \
# 0  0.00014046649389103441334797350847907182469498...
# 1  0.00014046649389103441334797350847907182469498...
# 2  0.00141207243460688205982656029391364427283406...
# 3  0.00141207243460688205982656029391364427283406...
# 4  -0.0065270235228747745803712376755356672219932...
#
#                                        net_pnl_quote  \
# 0  0.00530119919510114653848908972122444538399577...
# 1  0.00530119919510114653848908972122444538399577...
# 2  0.03815927443159518317461476044627488590776920...
# 3  0.03815927443159518317461476044627488590776920...
# 4  -0.2019866788812744728964787555014481768012046...
#
#                                       cum_fees_quote  \
# 0  0.02264397315653155981496347237680311081930994...
# 1  0.02264397315653155981496347237680311081930994...
# 2  0.01621415736037024393767502772334410110488533...
# 3  0.01621415736037024393767502772334410110488533...
# 4  0.01856772951775522914608096414212923264130949...
#
#                                  filled_amount_quote  is_active  is_trading  \
# 0   75.479910521771870435259188525378704071044921875      False       False
# 1   75.479910521771870435259188525378704071044921875      False       False
# 2  54.0471912012341562103756587021052837371826171875      False       False
# 3  54.0471912012341562103756587021052837371826171875      False       False
# 4     61.8924317258507699079927988350391387939453125      False       False
#
#                                          custom_info  close_timestamp  \
# 0  {'close_price': 0.5406, 'level_id': None, 'sid...       1745620140
# 1  {'close_price': 0.5406, 'level_id': None, 'sid...       1745620140
# 2  {'close_price': 0.5478, 'level_id': None, 'sid...       1745655180
# 3  {'close_price': 0.5478, 'level_id': None, 'sid...       1745655180
# 4  {'close_price': 0.5367, 'level_id': None, 'sid...       1745658660
#
#                 close_type controller_id side
# 0  CloseType.TRAILING_STOP          None  BUY
# 1  CloseType.TRAILING_STOP          None  BUY
# 2    CloseType.TAKE_PROFIT          None  BUY
# 3    CloseType.TAKE_PROFIT          None  BUY
# 4      CloseType.STOP_LOSS          None  BUY

# %% [markdown]
# ### Backtesting Analysis

# %% [markdown]
# ### Scatter of PNL per Trade
# This bar chart illustrates the PNL for each individual trade. Positive PNLs are shown in green and negative PNLs in red, providing a clear view of profitable vs. unprofitable trades.

# %%
import plotly.express as px

# Create a new column for profitability
executors_df['profitable'] = executors_df['net_pnl_quote'] > 0

# Create the scatter plot
fig = px.scatter(
    executors_df,
    x="timestamp",
    y='net_pnl_quote',
    title='PNL per Trade',
    color='profitable',
    color_discrete_map={True: 'green', False: 'red'},
    labels={'timestamp': 'Timestamp', 'net_pnl_quote': 'Net PNL (Quote)'},
    hover_data=['filled_amount_quote', 'side']
)

# Customize the layout
fig.update_layout(
    xaxis_title="Timestamp",
    yaxis_title="Net PNL (Quote)",
    legend_title="Profitable",
    font=dict(size=12, color="white"),
    showlegend=False,
    plot_bgcolor='rgba(0,0,0,0.8)',  # Dark background
    paper_bgcolor='rgba(0,0,0,0.8)',  # Dark background for the entire plot area
    xaxis=dict(gridcolor="gray"),
    yaxis=dict(gridcolor="gray")
)

# Add a horizontal line at y=0 to clearly separate profits and losses
fig.add_hline(y=0, line_dash="dash", line_color="lightgray")

# Show the plot
fig.show()

# %% [markdown]
# ### Histogram of PNL Distribution
# The histogram displays the distribution of PNL values across all trades. It helps in understanding the frequency and range of profit and loss outcomes.

# %%
fig = px.histogram(executors_df, x='net_pnl_quote', title='PNL Distribution')
fig.show()

# %% [markdown]
# # Conclusion
